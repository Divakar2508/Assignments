# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\Admin\Downloads\IPL Matches 2008-2020.csv")
df.head()
print("The mean is")
print(df.result_margin.mean())
print("The median is")
print(df.result_margin.median())
print("the mode is")
print(df.result_margin.mode())
print("The standard deviation is")
print(df.result_margin.std())
print("The variance is")
print(df.result_margin.var())
print("Skewness")
print(df.result_margin.skew())
print("Kurtosis")
print(df.result_margin.kurt())
# Out:
# The mean is
# 17.321652065081352
# The median is
# 8.0
# the mode is
# 0    6.0
# dtype: float64
# The standard deviation is
# 22.068426720518378
# The variance is
# 487.0154579188895
# Skewness
# 2.692045194891035
# Kurtosis
# 8.359212831425296
